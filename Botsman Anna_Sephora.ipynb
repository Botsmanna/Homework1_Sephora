# %% [markdown]
# # <font color=blue>Домашнее задание №1</font>
# <font color=red>**Sephora** website dataset</font>

# %% [markdown]
# ### 1. Импортируем библиотеки NumPy & Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 2. Импортируем сам датасет

# %%
sephora = pd.read_csv('sephora_website_dataset.csv')
sephora
# Out:
#            id               brand            category  \
# 0     2218774      Acqua Di Parma           Fragrance
# 1     2044816      Acqua Di Parma             Cologne
# 2     1417567      Acqua Di Parma             Perfume
# 3     1417617      Acqua Di Parma             Perfume
# 4     2218766      Acqua Di Parma           Fragrance
# ...       ...                 ...                 ...
# 9163  2208502  SEPHORA COLLECTION          Face Masks
# 9164  2298909  SEPHORA COLLECTION            Lip Sets
# 9165  2236750  SEPHORA COLLECTION  Tinted Moisturizer
# 9166       50  SEPHORA COLLECTION         no category
# 9167      304  SEPHORA COLLECTION         no category
#
#                                             name              size  rating  \
# 0                 Blu Mediterraneo MINIATURE Set    5 x 0.16oz/5mL     4.0
# 1                                        Colonia     0.7 oz/ 20 mL     4.5
# 2                               Arancia di Capri      5 oz/ 148 mL     4.5
# ...

# %% [markdown]
# ### 3. Cмотрим информацию про наш датасет, а также кол-во колонок и рядов

# %%
sephora.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9168 entries, 0 to 9167
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      9168 non-null   int64
#  1   brand                   9168 non-null   object
#  2   category                9168 non-null   object
#  3   name                    9168 non-null   object
#  4   size                    9168 non-null   object
#  5   rating                  9168 non-null   float64
#  6   number_of_reviews       9168 non-null   int64
#  7   love                    9168 non-null   int64
#  8   price                   9168 non-null   float64
#  9   value_price             9168 non-null   float64
#  10  URL                     9168 non-null   object
#  11  MarketingFlags          9168 non-null   bool
#  12  MarketingFlags_content  9168 non-null   object
#  13  options                 9168 non-null   object
# ...

# %%
sephora.shape
# Out:
# (9168, 21)

# %% [markdown]
# ### 4. Добавляем новую колонку limited, которая будет означать, что продукт в принципе лимитированный (не важно по кол-ву или по времени)

# %%
sephora['limited'] = sephora['limited_edition'] + sephora['limited_time_offer']
sephora
# Out:
#            id               brand            category  \
# 0     2218774      Acqua Di Parma           Fragrance
# 1     2044816      Acqua Di Parma             Cologne
# 2     1417567      Acqua Di Parma             Perfume
# 3     1417617      Acqua Di Parma             Perfume
# 4     2218766      Acqua Di Parma           Fragrance
# ...       ...                 ...                 ...
# 9163  2208502  SEPHORA COLLECTION          Face Masks
# 9164  2298909  SEPHORA COLLECTION            Lip Sets
# 9165  2236750  SEPHORA COLLECTION  Tinted Moisturizer
# 9166       50  SEPHORA COLLECTION         no category
# 9167      304  SEPHORA COLLECTION         no category
#
#                                             name              size  rating  \
# 0                 Blu Mediterraneo MINIATURE Set    5 x 0.16oz/5mL     4.0
# 1                                        Colonia     0.7 oz/ 20 mL     4.5
# 2                               Arancia di Capri      5 oz/ 148 mL     4.5
# ...

# %% [markdown]
# ### 5. Смотрим, какие колонки теперь у нас есть

# %%
sephora.columns
# Out:
# Index(['id', 'brand', 'category', 'name', 'size', 'rating',
#        'number_of_reviews', 'love', 'price', 'value_price', 'URL',
#        'MarketingFlags', 'MarketingFlags_content', 'options', 'details',
#        'how_to_use', 'ingredients', 'online_only', 'exclusive',
#        'limited_edition', 'limited_time_offer', 'limited'],
#       dtype='object')

# %% [markdown]
# ### 6. Сократим названия колонок

# %%
sephora.columns = ['id', 'brand', 'cat', 'name', 'size', 'rating', 'reviews', 'love', 'price', 
                   'v_price', 'URL', 'MF', 'MF_content', 'opt', 'details', 'htu', 'ingr', 'online', 
                   'excl', 'ltd_edition', 'ltd_time', 'ltd']
sephora
# Out:
#            id               brand                 cat  \
# 0     2218774      Acqua Di Parma           Fragrance
# 1     2044816      Acqua Di Parma             Cologne
# 2     1417567      Acqua Di Parma             Perfume
# 3     1417617      Acqua Di Parma             Perfume
# 4     2218766      Acqua Di Parma           Fragrance
# ...       ...                 ...                 ...
# 9163  2208502  SEPHORA COLLECTION          Face Masks
# 9164  2298909  SEPHORA COLLECTION            Lip Sets
# 9165  2236750  SEPHORA COLLECTION  Tinted Moisturizer
# 9166       50  SEPHORA COLLECTION         no category
# 9167      304  SEPHORA COLLECTION         no category
#
#                                             name              size  rating  \
# 0                 Blu Mediterraneo MINIATURE Set    5 x 0.16oz/5mL     4.0
# 1                                        Colonia     0.7 oz/ 20 mL     4.5
# 2                               Arancia di Capri      5 oz/ 148 mL     4.5
# ...

# %% [markdown]
# ### 7. Посмотрим данные 15-го продукта

# %%
sephora.iloc[15]
# Out:
# id                                                       2295228
# brand                                             Acqua Di Parma
# cat                                                    Fragrance
# name           Blu Mediterraneo Discovery Collection Rollerba...
# size                                                     no size
# rating                                                       4.0
# reviews                                                        1
# love                                                         594
# price                                                       80.0
# v_price                                                     95.0
# URL            https://www.sephora.com/product/blu-mediterran...
# MF                                                          True
# MF_content             limited edition · exclusive · online only
# opt                                                   no options
# ...

# %%
sephora.loc[15]
# Out:
# id                                                       2295228
# brand                                             Acqua Di Parma
# cat                                                    Fragrance
# name           Blu Mediterraneo Discovery Collection Rollerba...
# size                                                     no size
# rating                                                       4.0
# reviews                                                        1
# love                                                         594
# price                                                       80.0
# v_price                                                     95.0
# URL            https://www.sephora.com/product/blu-mediterran...
# MF                                                          True
# MF_content             limited edition · exclusive · online only
# opt                                                   no options
# ...

# %%
sephora.iloc[15, 3]
# Out:
# 'Blu Mediterraneo Discovery Collection Rollerball Set'

# %%
sephora['name'][15]
# Out:
# 'Blu Mediterraneo Discovery Collection Rollerball Set'

# %% [markdown]
# ### 8. Посмотрим данные десяти первых продуктов

# %%
sephora.head(10)
# Out:
#         id           brand                    cat  \
# 0  2218774  Acqua Di Parma              Fragrance
# 1  2044816  Acqua Di Parma                Cologne
# 2  1417567  Acqua Di Parma                Perfume
# 3  1417617  Acqua Di Parma                Perfume
# 4  2218766  Acqua Di Parma              Fragrance
# 5  1417609  Acqua Di Parma                Perfume
# 6  1638832  Acqua Di Parma                Perfume
# 7  1284462  Acqua Di Parma                Cologne
# 8  2221588  Acqua Di Parma  Body Mist & Hair Mist
# 9  2221596  Acqua Di Parma                Perfume
#
#                              name            size  rating  reviews  love  \
# 0  Blu Mediterraneo MINIATURE Set  5 x 0.16oz/5mL     4.0        4  3002
# 1                         Colonia   0.7 oz/ 20 mL     4.5       76  2700
# 2                Arancia di Capri    5 oz/ 148 mL     4.5       26  2600
# 3                Mirto di Panarea   2.5 oz/ 74 mL     4.5       23  2900
# ...

# %% [markdown]
# ### 9. Посмотрим данные десяти последних продуктов

# %%
sephora.tail(10)
# Out:
#            id               brand                       cat  \
# 9158  1867464  SEPHORA COLLECTION     Sponges & Applicators
# 9159  2102804  SEPHORA COLLECTION  Body Lotions & Body Oils
# 9160  2149847  SEPHORA COLLECTION  Bath Soaks & Bubble Bath
# 9161  1601111  SEPHORA COLLECTION                Brush Sets
# 9162  2149839  SEPHORA COLLECTION        Scrub & Exfoliants
# 9163  2208502  SEPHORA COLLECTION                Face Masks
# 9164  2298909  SEPHORA COLLECTION                  Lip Sets
# 9165  2236750  SEPHORA COLLECTION        Tinted Moisturizer
# 9166       50  SEPHORA COLLECTION               no category
# 9167      304  SEPHORA COLLECTION               no category
#
#                                                    name              size  \
# 9158                     The Sculptor - Airbrush Sponge           no size
# 9159               Moisturizing Body Milk - Beach Vibes   6.76 oz/ 200 mL
# 9160          Fizzing Bath Star Mini - Surprise Flowers        0.53oz/15g
# ...

# %% [markdown]
# ### 10. Выведем ряды с 515 по 530

# %%
sephora.iloc[515:530]
# Out:
#           id            brand                     cat  \
# 515  1499136  Atelier Cologne                 Perfume
# 516  1796317  Atelier Cologne           Bath & Shower
# 517  1480243       BALENCIAGA                 Perfume
# 518  1405851       BALENCIAGA                 Perfume
# 519  1922541     bareMinerals              Foundation
# 520  2176972     bareMinerals           BB & CC Cream
# 521  2241883     bareMinerals              Foundation
# 522  1922731     bareMinerals              Foundation
# 523  2241719     bareMinerals              Foundation
# 524  1073014     bareMinerals  Setting Spray & Powder
# 525  1727338     bareMinerals               Concealer
# 526  2040871     bareMinerals               Concealer
# 527  1002724     bareMinerals             Face Primer
# 528  2107662     bareMinerals              Foundation
# 529  2176774     bareMinerals              Foundation
#
#                                                   name            size  \
# ...

# %% [markdown]
# ### 11. Выведем колонку с наименованием продукта

# %%
sephora['name']
# Out:
# 0                   Blu Mediterraneo MINIATURE Set
# 1                                          Colonia
# 2                                 Arancia di Capri
# 3                                 Mirto di Panarea
# 4                            Colonia Miniature Set
#                            ...
# 9163                            The Rose Gold Mask
# 9164    Give Me Some Sugar Colorful Gloss Balm Set
# 9165                 Weekend Warrior Tone Up Cream
# 9166                                     Gift Card
# 9167                      Happy Birthday Gift Card
# Name: name, Length: 9168, dtype: object

# %% [markdown]
# ### 12. Смотрим уникальные категории продуктов

# %%
sephora['cat'].unique()
# Out:
# array(['Fragrance', 'Cologne', 'Perfume', 'Body Mist & Hair Mist',
#        'Body Lotions & Body Oils', 'Body Sprays & Deodorant',
#        'Perfume Gift Sets', 'no category', 'Rollerballs & Travel Size',
#        'Lip Balm & Treatment', 'Lotions & Oils', 'Eye Palettes',
#        'Highlighter', 'Cheek Palettes', 'Lipstick', 'Face Serums',
#        'Moisturizers', 'Value & Gift Sets', 'Eye Creams & Treatments',
#        'Face Sunscreen', 'Lip Balms & Treatments', 'Mini Size',
#        'Face Masks', 'Face Wash & Cleansers', 'Decollete & Neck Creams',
#        'Face Oils', 'Hand Cream & Foot Cream', 'Face Primer',
#        'Color Correct', 'Mists & Essences', 'Tinted Moisturizer',
#        'Concealer', 'Beauty Supplements', 'Facial Peels', 'Exfoliators',
#        'Conditioner', 'Shampoo', 'Hair Styling Products',
#        'Scalp & Hair Treatments', 'Hair Masks', 'Hair Spray', 'Hair Oil',
#        'Hair Primers', 'Dry Shampoo', 'Hair', 'Hair Thinning & Hair Loss',
# ...

# %% [markdown]
# ### 13. Выведем колонку с наименованием и понравившемся кол-вом

# %%
sephora[['name', 'love']]
# Out:
#                                             name  love
# 0                 Blu Mediterraneo MINIATURE Set  3002
# 1                                        Colonia  2700
# 2                               Arancia di Capri  2600
# 3                               Mirto di Panarea  2900
# 4                          Colonia Miniature Set   943
# ...                                          ...   ...
# 9163                          The Rose Gold Mask  6200
# 9164  Give Me Some Sugar Colorful Gloss Balm Set   266
# 9165               Weekend Warrior Tone Up Cream   445
# 9166                                   Gift Card     0
# 9167                    Happy Birthday Gift Card     0
#
# [9168 rows x 2 columns]

# %% [markdown]
# ### 14. Выберем только те продукты, которые эксклюзивно продаются на вебсайте Sephora

# %%
sephora[sephora['excl'] == 1]
# Out:
#            id               brand                 cat  \
# 9     2221596      Acqua Di Parma             Perfume
# 15    2295228      Acqua Di Parma           Fragrance
# 63    1957182            Algenist         Face Serums
# 64    2170827            Algenist        Moisturizers
# 65    2289643            Algenist   Value & Gift Sets
# ...       ...                 ...                 ...
# 9161  1601111  SEPHORA COLLECTION          Brush Sets
# 9162  2149839  SEPHORA COLLECTION  Scrub & Exfoliants
# 9163  2208502  SEPHORA COLLECTION          Face Masks
# 9164  2298909  SEPHORA COLLECTION            Lip Sets
# 9165  2236750  SEPHORA COLLECTION  Tinted Moisturizer
#
#                                                    name              size  \
# 9                                 Rosa Nobile Hair Mist        1.7oz/50mL
# 15    Blu Mediterraneo Discovery Collection Rollerba...           no size
# 63                               GENIUS Liquid Collagen           no size
# ...

# %%
sephora[sephora['excl'] == 1].shape
# Out:
# (2427, 22)

# %% [markdown]
# ###### Всего 2427 продукта продаются эксклюзивно на вебсайте Sephora, что соcтавляет около 27% всех продуктов, представленных на сайте

# %% [markdown]
# ### 15. Выберем только те эксклюзивные продукты, рейтинг которых выше 4.5

# %%
sephora[(sephora['excl'] == 1) & (sephora['rating'] > 4.5)]
# Out:
#            id               brand                cat  \
# 110   2289346            Algenist  Value & Gift Sets
# 233   1958040               amika      Curling Irons
# 465   2287175      Artist Couture       Eye Palettes
# 466   2328615     Atelier Cologne          Fragrance
# 472   2319606     Atelier Cologne          Fragrance
# ...       ...                 ...                ...
# 9122  1921584  SEPHORA COLLECTION        Eye Brushes
# 9123  1889351  SEPHORA COLLECTION       Face Brushes
# 9132  2046118  SEPHORA COLLECTION   Lid Shadow Brush
# 9137  1605096  SEPHORA COLLECTION               Nail
# 9143  2017010  SEPHORA COLLECTION        Highlighter
#
#                                                 name              size  \
# 110                           Algenist Weekender Kit           no size
# 233                            Curl Icon Barrel Pack           no size
# 465                 Midnight Maven Eyeshadow Palette  8 x 0.04 oz/ 1 g
# ...

# %%
sephora[(sephora['excl'] == 1) & (sephora['rating'] > 4.5)].shape
# Out:
# (230, 22)

# %% [markdown]
# ###### Всего на вебсайте Sephora представлено 230 эксклюзивных продуктов, рейтинг которых выше 4.5, что составляет почти 10% от общего кол-во эксклюзивных продуктов на сайте, следовательно, остальные 90% или 2197 продуктов имеют рейтинг ниже 4.5

# %% [markdown]
# ### 16. Выберем только те продукты, которые лимитированы по кол-ву и по времени продажи на сайте

# %%
sephora[(sephora['ltd_edition'] == 1) & (sephora['ltd_time'] == 1)]
# Out:
#            id             brand        cat                            name  \
# 4657  2226694  KVD Vegan Beauty  Face Sets  Crush - Technicolor Crayon Set
#
#          size  rating  reviews  love  price  v_price  ...  \
# 4657  no size     4.5       17  2700   34.0     34.0  ...
#
#                                             MF_content         opt  \
# 4657  limited time offer · limited edition · exclusive  no options
#
#                                                 details  \
# 4657  What it is: A trio of multipurpose pigment sti...
#
#                                                     htu     ingr online excl  \
# 4657  Suggested Usage:-Use Electric Blue on the eyes...  unknown      0    1
#
#       ltd_edition  ltd_time  ltd
# 4657            1         1    2
#
# [1 rows x 22 columns]

# %%
sephora[(sephora['ltd_edition'] == 1) & (sephora['ltd_time'] == 1)].shape
# Out:
# (1, 22)

# %% [markdown]
# ###### Всего на вебсайте Sephora представлен 1 продукт, который одновременно лиимтирован и по времени, и по кол-ву - набор карандашей для лица бренда KVD Vegan Beauty

# %% [markdown]
# ### 17. Выберем только те продукты, которые лимитированы либо по кол-во, либо по времени продажи на сайте

# %%
sephora[(sephora['ltd_edition'] == 1) | (sephora['ltd_time'] == 1)]
# Out:
#            id               brand                         cat  \
# 15    2295228      Acqua Di Parma                   Fragrance
# 20    2295210      Acqua Di Parma           Perfume Gift Sets
# 28    2295194      Acqua Di Parma           Perfume Gift Sets
# 31    2295202      Acqua Di Parma           Perfume Gift Sets
# 32    2295186      Acqua Di Parma           Perfume Gift Sets
# ...       ...                 ...                         ...
# 9143  2017010  SEPHORA COLLECTION                 Highlighter
# 9145  1919257  SEPHORA COLLECTION  Makeup Bags & Travel Cases
# 9154  1927904  SEPHORA COLLECTION                Eye Palettes
# 9161  1601111  SEPHORA COLLECTION                  Brush Sets
# 9163  2208502  SEPHORA COLLECTION                  Face Masks
#
#                                                    name                size  \
# 15    Blu Mediterraneo Discovery Collection Rollerba...             no size
# ...

# %%
sephora[(sephora['ltd_edition'] == 1) | (sephora['ltd_time'] == 1)].shape
# Out:
# (844, 22)

# %% [markdown]
# ###### Всего на вебсайте Sephora представлено 844 лимитированных по кол-ву либо по времени продукта или 9% от всей продукции на сайте.

# %% [markdown]
# ### 18. Выберем только те продукты, которые не лимитированы

# %%
sephora[~((sephora['ltd_edition'] == 1) | (sephora['ltd_time'] == 1))]
# Out:
#            id               brand                 cat  \
# 0     2218774      Acqua Di Parma           Fragrance
# 1     2044816      Acqua Di Parma             Cologne
# 2     1417567      Acqua Di Parma             Perfume
# 3     1417617      Acqua Di Parma             Perfume
# 4     2218766      Acqua Di Parma           Fragrance
# ...       ...                 ...                 ...
# 9162  2149839  SEPHORA COLLECTION  Scrub & Exfoliants
# 9164  2298909  SEPHORA COLLECTION            Lip Sets
# 9165  2236750  SEPHORA COLLECTION  Tinted Moisturizer
# 9166       50  SEPHORA COLLECTION         no category
# 9167      304  SEPHORA COLLECTION         no category
#
#                                                    name              size  \
# 0                        Blu Mediterraneo MINIATURE Set    5 x 0.16oz/5mL
# 1                                               Colonia     0.7 oz/ 20 mL
# 2                                      Arancia di Capri      5 oz/ 148 mL
# ...

# %%
sephora[~((sephora['ltd_edition'] == 1) | (sephora['ltd_time'] == 1))].shape
# Out:
# (8324, 22)

# %% [markdown]
# ###### Всего на вебсайте Sephora представлено 8324 продукта или 91%, которые не лимитированы. Соответственно, большинство продуктов, представленных на сайте Sephora - не лимитированные.

# %% [markdown]
# ### 19. Выберем только те эксклюзивные продукты, рейтинг которых выше 4.5, а также кол-во лайков которых превышает 1000

# %%
sephora[(sephora['excl'] == 1) 
          & (sephora['love'] > 1000) 
          & (sephora['rating'] > 4.5)]
# Out:
#            id               brand                     cat  \
# 233   1958040               amika           Curling Irons
# 465   2287175      Artist Couture            Eye Palettes
# 466   2328615     Atelier Cologne               Fragrance
# 505   1447895     Atelier Cologne                 Perfume
# 541   2308567        bareMinerals  Setting Spray & Powder
# ...       ...                 ...                     ...
# 9122  1921584  SEPHORA COLLECTION             Eye Brushes
# 9123  1889351  SEPHORA COLLECTION            Face Brushes
# 9132  2046118  SEPHORA COLLECTION        Lid Shadow Brush
# 9137  1605096  SEPHORA COLLECTION                    Nail
# 9143  2017010  SEPHORA COLLECTION             Highlighter
#
#                                                 name              size  \
# 233                            Curl Icon Barrel Pack           no size
# 465                 Midnight Maven Eyeshadow Palette  8 x 0.04 oz/ 1 g
# ...

# %%
sephora[(sephora['excl'] == 1) 
          & (sephora['love'] > 1000) 
          & (sephora['rating'] > 4.5)].shape
# Out:
# (161, 22)

# %% [markdown]
# ###### Всего на вебсайте Sephora представлен 161 эксклюзивный продукт или почти 7% от всей эксклюзивной продукции на сайте с рейтингом выше 4.5 и кол-вом лайков выше 1000.

# %% [markdown]
# ### 20. Посмотрим кол-во эксклюзивных продуктов, чей рейтинг составляет от 0 и до 3.9

# %%
sephora[(sephora['excl'] == 1) 
        & (sephora['rating'].isin(range(0, 4)))]
# Out:
#            id               brand                 cat  \
# 9     2221596      Acqua Di Parma             Perfume
# 72    2338317            Algenist           Mini Size
# 369   2319465       Armani Beauty   Perfume Gift Sets
# 464   2195956      Artist Couture           Lip Gloss
# 475   2294346     Atelier Cologne   Perfume Gift Sets
# ...       ...                 ...                 ...
# 9105  2290096  SEPHORA COLLECTION         Eye Brushes
# 9108  2232007  SEPHORA COLLECTION  Beauty Supplements
# 9163  2208502  SEPHORA COLLECTION          Face Masks
# 9164  2298909  SEPHORA COLLECTION            Lip Sets
# 9165  2236750  SEPHORA COLLECTION  Tinted Moisturizer
#
#                                                    name              size  \
# 9                                 Rosa Nobile Hair Mist        1.7oz/50mL
# 72                         Mini GENIUS Liquid Collagen            no size
# 369    Si Passione Eau de Parfum & Lip Maestro Gift Set           no size
# ...

# %%
sephora[(sephora['excl'] == 1) 
        & (sephora['rating'].isin(range(0, 4)))].shape
# Out:
# (212, 22)

# %% [markdown]
# ###### Всего на вебсайте Sephora представлено 212 эксклюзивных продуктов или почти 9% от всей эксклюзивной продукции на сайте с рейтингом от 0 до 3.9

# %% [markdown]
# ### 21. Отсортируем наши данные по кол-ву убывания лайков

# %%
sephora['love'].sort_values(ascending=False)
# Out:
# 4602    1300000
# 5837     770700
# 272      660000
# 4952     657100
# 5842     646600
#          ...
# 2765          0
# 2686          0
# 2636          0
# 7062          0
# 9167          0
# Name: love, Length: 9168, dtype: int64

# %%
sephora.sort_values(by=['love'], ascending=False)
# Out:
#            id                    brand                        cat  \
# 4602  1890623         KVD Vegan Beauty                   Lipstick
# 5837  2172310                     NARS                  Concealer
# 272   1056084  Anastasia Beverly Hills                    Eyebrow
# 4952   870618            Laura Mercier     Setting Spray & Powder
# 5842   899393                     NARS                      Blush
# ...       ...                      ...                        ...
# 2765  2155661                  Eve Lom                   Skincare
# 2686  2111862             Estée Lauder                  Mini Size
# 2636  2044014           ELLIS BROOKLYN  Rollerballs & Travel Size
# 7062  2070100       SEPHORA COLLECTION                 Face Wipes
# 9167      304       SEPHORA COLLECTION                no category
#
#                                                    name               size  \
# 4602                        Everlasting Liquid Lipstick    0.22 oz/ 6.6 mL
# ...

# %% [markdown]
# ###### Можем заметить, что наибольше кол-во лайков в виде 1 300 000 набрала жидкая помада KVD Vegan Beauy.

# %% [markdown]
# ### 22. Отсортируем наши данные по кол-ву убывания лайков и рейтинга

# %%
sephora.sort_values(by=['love', 'rating'], ascending=[False, False])
# Out:
#            id                    brand                        cat  \
# 4602  1890623         KVD Vegan Beauty                   Lipstick
# 5837  2172310                     NARS                  Concealer
# 272   1056084  Anastasia Beverly Hills                    Eyebrow
# 4952   870618            Laura Mercier     Setting Spray & Powder
# 5842   899393                     NARS                      Blush
# ...       ...                      ...                        ...
# 7226      443       SEPHORA COLLECTION                no category
# 8263  2175735                 TOM FORD  Rollerballs & Travel Size
# 8501  2234730              Urban Decay                   Eyeliner
# 8639  1233162              Viktor&Rolf             Lotions & Oils
# 9167      304       SEPHORA COLLECTION                no category
#
#                                                    name               size  \
# 4602                        Everlasting Liquid Lipstick    0.22 oz/ 6.6 mL
# ...

# %% [markdown]
# ###### В топ три продукта по кол-ву лайков и рейтинга на вебсайте Sephora вошли:
# 1. KVD Vegan Beauty с жидкой помадой
# 2. NARS с консилером
# 3. Anastasia Beverly Hills с карандашом для бровей

# %% [markdown]
# ### 23. Удалим колонку с ссылкой на продукт, потому что она нам не интересна

# %%
del sephora['URL']
sephora.head()
# Out:
#         id           brand        cat                            name  \
# 0  2218774  Acqua Di Parma  Fragrance  Blu Mediterraneo MINIATURE Set
# 1  2044816  Acqua Di Parma    Cologne                         Colonia
# 2  1417567  Acqua Di Parma    Perfume                Arancia di Capri
# 3  1417617  Acqua Di Parma    Perfume                Mirto di Panarea
# 4  2218766  Acqua Di Parma  Fragrance           Colonia Miniature Set
#
#              size  rating  reviews  love  price  v_price  ...   MF_content  \
# 0  5 x 0.16oz/5mL     4.0        4  3002   66.0     75.0  ...  online only
# 1   0.7 oz/ 20 mL     4.5       76  2700   66.0     66.0  ...  online only
# 2    5 oz/ 148 mL     4.5       26  2600  180.0    180.0  ...  online only
# 3   2.5 oz/ 74 mL     4.5       23  2900  120.0    120.0  ...  online only
# 4  5 x 0.16oz/5mL     3.5        2   943   72.0     80.0  ...  online only
#
#                                                  opt  \
# ...

# %%
sephora.columns
# Out:
# Index(['id', 'brand', 'cat', 'name', 'size', 'rating', 'reviews', 'love',
#        'price', 'v_price', 'MF', 'MF_content', 'opt', 'details', 'htu', 'ingr',
#        'online', 'excl', 'ltd_edition', 'ltd_time', 'ltd'],
#       dtype='object')

# %% [markdown]
# ### 24. Создадим бинарные переменные по кол-ву лайков
# high - > 1000, medium - 500-1000, low - <500

# %%
sephora['love'].apply(lambda x: 1 if x >=1000 else 0).sum()
# Out:
# 7631

# %%
sephora['love'].apply(lambda x: 1 if x in range(500,1000) else 0).sum()
# Out:
# 719

# %%
sephora['love'].apply(lambda x: 1 if x <=500 else 0).sum()
# Out:
# 818

# %%
sephora['h_love'] = sephora['love'].apply(lambda x: 1 if x >=1000 else 0)

# %%
sephora['m_love'] = sephora['love'].apply(lambda x: 1 if x in range(500,1000) else 0)

# %%
sephora['l_love'] = sephora['love'].apply(lambda x: 1 if x <=500 else 0)

# %%
sephora.head()
# Out:
#         id           brand        cat                            name  \
# 0  2218774  Acqua Di Parma  Fragrance  Blu Mediterraneo MINIATURE Set
# 1  2044816  Acqua Di Parma    Cologne                         Colonia
# 2  1417567  Acqua Di Parma    Perfume                Arancia di Capri
# 3  1417617  Acqua Di Parma    Perfume                Mirto di Panarea
# 4  2218766  Acqua Di Parma  Fragrance           Colonia Miniature Set
#
#              size  rating  reviews  love  price  v_price  ...  \
# 0  5 x 0.16oz/5mL     4.0        4  3002   66.0     75.0  ...
# 1   0.7 oz/ 20 mL     4.5       76  2700   66.0     66.0  ...
# 2    5 oz/ 148 mL     4.5       26  2600  180.0    180.0  ...
# 3   2.5 oz/ 74 mL     4.5       23  2900  120.0    120.0  ...
# 4  5 x 0.16oz/5mL     3.5        2   943   72.0     80.0  ...
#
#                                                  htu  \
# 0  Suggested Usage:-Fragrance is intensified by t...
# 1                                    no instructions
# ...

# %% [markdown]
# ##### 83% продуктов понравились более 1000 пользователей сайта Sephora; 8% понравились более 500 пользователей, но менее 1000; 9% понравились менее 500 пользователей

# %% [markdown]
# ### 25. Создадим категориальную переменную на основе количественной по кол-ву лайков

# %%
sephora['love_cat'] = sephora['love']
sephora
# Out:
#            id               brand                 cat  \
# 0     2218774      Acqua Di Parma           Fragrance
# 1     2044816      Acqua Di Parma             Cologne
# 2     1417567      Acqua Di Parma             Perfume
# 3     1417617      Acqua Di Parma             Perfume
# 4     2218766      Acqua Di Parma           Fragrance
# ...       ...                 ...                 ...
# 9163  2208502  SEPHORA COLLECTION          Face Masks
# 9164  2298909  SEPHORA COLLECTION            Lip Sets
# 9165  2236750  SEPHORA COLLECTION  Tinted Moisturizer
# 9166       50  SEPHORA COLLECTION         no category
# 9167      304  SEPHORA COLLECTION         no category
#
#                                             name              size  rating  \
# 0                 Blu Mediterraneo MINIATURE Set    5 x 0.16oz/5mL     4.0
# 1                                        Colonia     0.7 oz/ 20 mL     4.5
# 2                               Arancia di Capri      5 oz/ 148 mL     4.5
# ...

# %%
def get_love_cat(love):
    if love >= 1000:
        return 'high'
    elif love in range(500,1000):
        return 'medium'
    elif love < 500:
        return 'low'
    else:
        return love

# %%
sephora['love'].apply(get_love_cat)
# Out:
# 0         high
# 1         high
# 2         high
# 3         high
# 4       medium
#          ...
# 9163      high
# 9164       low
# 9165       low
# 9166       low
# 9167       low
# Name: love, Length: 9168, dtype: object

# %%
sephora['love'] = sephora['love'].apply(get_love_cat)
sephora.head()
# Out:
#         id           brand        cat                            name  \
# 0  2218774  Acqua Di Parma  Fragrance  Blu Mediterraneo MINIATURE Set
# 1  2044816  Acqua Di Parma    Cologne                         Colonia
# 2  1417567  Acqua Di Parma    Perfume                Arancia di Capri
# 3  1417617  Acqua Di Parma    Perfume                Mirto di Panarea
# 4  2218766  Acqua Di Parma  Fragrance           Colonia Miniature Set
#
#              size  rating  reviews    love  price  v_price  ...  \
# 0  5 x 0.16oz/5mL     4.0        4    high   66.0     75.0  ...
# 1   0.7 oz/ 20 mL     4.5       76    high   66.0     66.0  ...
# 2    5 oz/ 148 mL     4.5       26    high  180.0    180.0  ...
# 3   2.5 oz/ 74 mL     4.5       23    high  120.0    120.0  ...
# 4  5 x 0.16oz/5mL     3.5        2  medium   72.0     80.0  ...
#
#                                                 ingr online excl ltd_edition  \
# 0  Arancia di Capri Eau de Toilette: Alcohol Dena...      1    0           0
# ...

# %%
sephora['love'] = pd.Categorical(sephora['love'])

# %%
sephora.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9168 entries, 0 to 9167
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           9168 non-null   int64
#  1   brand        9168 non-null   object
#  2   cat          9168 non-null   object
#  3   name         9168 non-null   object
#  4   size         9168 non-null   object
#  5   rating       9168 non-null   float64
#  6   reviews      9168 non-null   int64
#  7   love         9168 non-null   category
#  8   price        9168 non-null   float64
#  9   v_price      9168 non-null   float64
#  10  MF           9168 non-null   bool
#  11  MF_content   9168 non-null   object
#  12  opt          9168 non-null   object
#  13  details      9168 non-null   object
#  14  htu          9168 non-null   object
#  15  ingr         9168 non-null   object
#  16  online       9168 non-null   int64
#  17  excl         9168 non-null   int64
# ...

# %%
sephora['love']
# Out:
# 0         high
# 1         high
# 2         high
# 3         high
# 4       medium
#          ...
# 9163      high
# 9164       low
# 9165       low
# 9166       low
# 9167       low
# Name: love, Length: 9168, dtype: category
# Categories (3, object): ['high', 'low', 'medium']

# %%
sephora['love'].cat.codes
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       2
#        ..
# 9163    0
# 9164    1
# 9165    1
# 9166    1
# 9167    1
# Length: 9168, dtype: int8

# %%
sephora['love'].cat.categories
# Out:
# Index(['high', 'low', 'medium'], dtype='object')

# %% [markdown]
# ### 26. Создадим  переменную на основе 2-колонок, которая будет показывать - продукт или эксклюзивный, или лимитированный (по времени или по кол-ву)

# %%
sephora['excep'] = np.where((sephora['excl'] == 1 )&
         (sephora['ltd'] == 1), 1, 0)

# %%
sephora.head()
# Out:
#         id           brand        cat                            name  \
# 0  2218774  Acqua Di Parma  Fragrance  Blu Mediterraneo MINIATURE Set
# 1  2044816  Acqua Di Parma    Cologne                         Colonia
# 2  1417567  Acqua Di Parma    Perfume                Arancia di Capri
# 3  1417617  Acqua Di Parma    Perfume                Mirto di Panarea
# 4  2218766  Acqua Di Parma  Fragrance           Colonia Miniature Set
#
#              size  rating  reviews    love  price  v_price  ...  online excl  \
# 0  5 x 0.16oz/5mL     4.0        4    high   66.0     75.0  ...       1    0
# 1   0.7 oz/ 20 mL     4.5       76    high   66.0     66.0  ...       1    0
# 2    5 oz/ 148 mL     4.5       26    high  180.0    180.0  ...       1    0
# 3   2.5 oz/ 74 mL     4.5       23    high  120.0    120.0  ...       1    0
# 4  5 x 0.16oz/5mL     3.5        2  medium   72.0     80.0  ...       1    0
#
#   ltd_edition ltd_time ltd h_love  m_love  l_love  love_cat  excep
# ...

# %%
sephora['excep'].sum()
# Out:
# 416

# %% [markdown]
# ###### На сайте Sephora представлено 416 продуктов или 5% от всех продуктов, которые экслюзивные и лимитированные (по времени продажи или по кол-ву)

# %% [markdown]
# ### 27. Группировка данных. Узнаем сколько продуктов с большим кол-вом лайков продаются только онлайн

# %%
sephora['love'].value_counts()
# Out:
# high      7631
# low        818
# medium     719
# Name: love, dtype: int64

# %%
sephora['online'].value_counts()
# Out:
# 0    7015
# 1    2153
# Name: online, dtype: int64

# %%
sephora.groupby('love')['online'].sum()
# Out:
# love
# high      1459
# low        394
# medium     300
# Name: online, dtype: int64

# %%
sephora.groupby('love')['online'].value_counts()
# Out:
# love    online
# high    0         6172
#         1         1459
# low     0          424
#         1          394
# medium  0          419
#         1          300
# Name: online, dtype: int64

# %% [markdown]
# ###### Онлайн продаются 19% продуктов с большим кол-вом лайков , почти 42% продуктов со средним кол-вом лайков и 48% продуктов с маленьким кол-вом лайков

# %% [markdown]
# ### 28. Визуализируем полученные данные

# %%
sephora['love'].hist()
# Out:
# <AxesSubplot:>

# %%
sephora['rating'].hist()
# Out:
# <AxesSubplot:>

# %%
sephora['love'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sephora.groupby('love').size().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='love'>

# %%
sephora.groupby('online')['love'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='online,None'>

# %%
sephora.groupby('online')['love'].value_counts().unstack()
# Out:
#         high  low  medium
# online
# 0       6172  424     419
# 1       1459  394     300

# %%
sephora.groupby('online')['love'].value_counts().unstack().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='online'>

# %%
sephora.groupby('online')['love'].value_counts().unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='online'>

# %% [markdown]
# ### 29. Найдем среднее арифметическое цены продуктов, представленных на сайте Sephora

# %%
sephora['price'].sum() / len(sephora['price'])
# Out:
# 50.06323734729494

# %%
sephora['price'].mean()
# Out:
# 50.063237347294915

# %% [markdown]
# ###### Средняя цена продукции, представленной на сайте, - 50$

# %% [markdown]
# ### 30. Найдем медиану цены продукции на сайте

# %%
price_sorted = sephora['price'].sort_values().reset_index(drop=True)
print(len(price_sorted))
ind_1, ind_2 = int(len(price_sorted) / 2), int(len(price_sorted)/ 2 + 1)
print(ind_1, ind_2)
print((price_sorted[ind_1] + price_sorted[ind_2]) / 2)
# Out:
# 9168
# 4584 4585
# 35.0

# %%
sephora['price'].median()
# Out:
# 35.0

# %% [markdown]
# ######  35 долларов стоят 50% или меньше продукции, представленной на сайте; 35 долларов стоят 50% или больше продукции, представленной на сайте

# %% [markdown]
# ### 31. Найдем моду цены продукции на сайте

# %%
sephora['price'].value_counts()
# Out:
# 25.00     346
# 28.00     334
# 30.00     333
# 29.00     259
# 38.00     255
#          ...
# 111.00      1
# 151.00      1
# 144.00      1
# 182.00      1
# 4.95        1
# Name: price, Length: 286, dtype: int64

# %%
sephora['price'].mode()
# Out:
# 0    25.0
# Name: price, dtype: float64

# %%
sephora['price'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### На сайте Sephora чаще всего встречаются продукты стоимостью 25$

# %%
sephora[['price', 'v_price', 'love_cat']].describe()
# Out:
#              price     v_price      love_cat
# count  9168.000000  9168.00000  9.168000e+03
# mean     50.063237    51.82359  1.627859e+04
# std      47.164989    49.45902  4.260651e+04
# min       2.000000     2.00000  0.000000e+00
# 25%      24.000000    25.00000  1.600000e+03
# 50%      35.000000    35.00000  4.800000e+03
# 75%      59.000000    60.00000  1.380000e+04
# max     549.000000   549.00000  1.300000e+06

# %%
sephora['price'].describe()
# Out:
# count    9168.000000
# mean       50.063237
# std        47.164989
# min         2.000000
# 25%        24.000000
# 50%        35.000000
# 75%        59.000000
# max       549.000000
# Name: price, dtype: float64

# %% [markdown]
# ### 32. Сгруппируем данные и определим влияет ли цена продукта на кол-во лайков и отзывов на продукты

# %%
sephora.groupby(['love_cat', 'reviews'])['price'].mean()
# Out:
# love_cat  reviews
# 0         0          30.203704
#           1          20.571429
#           2          21.600000
#           3          29.285714
#           4          20.642857
#                        ...
# 646600    17000      30.000000
# 657100    8000       39.000000
# 660000    14000      23.000000
# 770700    11000      30.000000
# 1300000   14000      21.000000
# Name: price, Length: 7389, dtype: float64

# %%
sephora.groupby(['love_cat', 'reviews'])['price'].agg(lambda x: x.value_counts().index[0])
# Out:
# love_cat  reviews
# 0         0          14.0
#           1          29.0
#           2          18.0
#           3          30.0
#           4          27.0
#                      ...
# 646600    17000      30.0
# 657100    8000       39.0
# 660000    14000      23.0
# 770700    11000      30.0
# 1300000   14000      21.0
# Name: price, Length: 7389, dtype: float64

# %%
sephora.groupby('price')[['love_cat', 'reviews']].agg(lambda x: x.value_counts().index[0])
# Out:
#         love_cat  reviews
# price
# 2.00       30600      199
# 3.00           0        7
# 3.50       18900     1000
# 3.95        8300       25
# 4.00        8700       71
# ...          ...      ...
# 450.00       594        5
# 460.00      2300        9
# 495.00      1700       27
# 499.00     11200       67
# 549.00     50400      496
#
# [286 rows x 2 columns]

# %%
sephora.groupby('love')['price'].agg(['mean', 'median'])
# Out:
#              mean  median
# love
# high    47.740633    34.0
# low     59.160134    40.0
# medium  64.364395    44.0

# %%
sephora.groupby('reviews')['price'].agg(['mean', 'median'])
# Out:
#               mean  median
# reviews
# 0        55.461713    38.0
# 1        65.981949    39.0
# 2        68.972017    42.0
# 3        60.037932    43.0
# 4        57.469340    39.0
# ...            ...     ...
# 13000    13.000000    13.0
# 14000    27.000000    23.0
# 15000    26.750000    25.0
# 17000    25.500000    25.5
# 19000    32.000000    32.0
#
# [833 rows x 2 columns]

# %%
sephora.pivot_table(index='price',
                   values=['love', 'reviews'],
                   aggfunc=['mean', 'median'])
# Out:
#                mean  median
#             reviews reviews
# price
# 2.00     105.000000   105.0
# 3.00     222.375000    69.0
# 3.50    1000.000000  1000.0
# 3.95      25.000000    25.0
# 4.00     134.666667    71.0
# ...             ...     ...
# 450.00     5.000000     5.0
# 460.00     9.000000     9.0
# 495.00    27.000000    27.0
# 499.00    67.000000    67.0
# 549.00   496.000000   496.0
#
# [286 rows x 2 columns]

# %% [markdown]
# ###### Можем увидеть, что цена на самом деле не влияет на кол-во лайков и отзывов, люди добавляют товары в избранное/лайкают и оставляют комментарии вне зависимости от цены.

# %% [markdown]
# ### 33. Определим меры разброса

# %%
sephora.groupby('price')['love_cat'].sum()
# Out:
# price
# 2.00      32700
# 3.00      85900
# 3.50      18900
# 3.95       8300
# 4.00      32800
#           ...
# 450.00      594
# 460.00     2300
# 495.00     1700
# 499.00    11200
# 549.00    50400
# Name: love_cat, Length: 286, dtype: int64

# %%
sephora.groupby('love')['price'].agg(lambda x: x.value_counts().index[0])
# Out:
# love
# high      25.0
# low       30.0
# medium    30.0
# Name: price, dtype: float64

# %%
sephora_love = pd.DataFrame(sephora.groupby('love')['price'].agg(lambda x: x.value_counts().index[0]))

# %%
sephora_love.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='love'>

# %%
sephora_love['price'].max() - sephora_love['price'].min()
# Out:
# 5.0

# %% [markdown]
# ###### 5 долларов размах нашей переменной или цены в зависимости от кол-ва лайков

# %%
sephora_love.describe()['price']['25%']
# Out:
# 27.5

# %%
np.percentile(sephora_love['price'], 25)
# Out:
# 27.5

# %%
np.percentile(sephora_love['price'], 75) - np.percentile(sephora_love['price'], 25)
# Out:
# 2.5

# %% [markdown]
# ###### интерквартильный размах = 2.5$

# %%
sephora_mean = sephora_love['price'].mean()
deviations = sephora_love['price'] - sephora_mean
sq_deviations = deviations ** 2
variance_samp = sq_deviations.sum() / (len(sephora_love) - 1)
std_samp = np.sqrt(variance_samp)
print(variance_samp, std_samp)
# Out:
# 8.333333333333334 2.886751345948129

# %%
variance_pop = sq_deviations.sum() / (len(sephora_love))
std_pop = np.sqrt(variance_pop)
print(variance_pop, std_pop)
# Out:
# 5.555555555555556 2.3570226039551585

# %%
print(sephora_love['price'].var())
print(sephora_love['price'].std())
# Out:
# 8.333333333333334
# 2.886751345948129

# %%
print(sephora_love['price'].var(ddof=0))
print(sephora_love['price'].std(ddof=0))
# Out:
# 5.555555555555556
# 2.3570226039551585

# %%
sephora.groupby('love')['price'].std()
# Out:
# love
# high      44.298342
# low       58.427233
# medium    57.509949
# Name: price, dtype: float64

# %%
sephora.groupby('love')['price'].agg(['mean', 'std'])
# Out:
#              mean        std
# love
# high    47.740633  44.298342
# low     59.160134  58.427233
# medium  64.364395  57.509949

# %%
def range_values(x):
    return x.max() - x.min()

sephora.pivot_table(index='price',
                   values=['reviews', 'love_cat'],
                   aggfunc=['var', 'std', range_values])
# Out:
#                 var                          std             range_values  \
#            love_cat        reviews      love_cat     reviews     love_cat
# price
# 2.0    4.061250e+08   17672.000000  20152.543264  132.936075        28500
# 3.0    1.775627e+08   94653.410714  13325.264672  307.657944        36600
# 4.0    9.116333e+07   29122.333333   9547.949169  170.652669        18700
# 5.0    3.675906e+08  108593.447619  19172.652895  329.535199        57300
# 5.8    9.177233e+08   84256.333333  30293.948791  290.269415        57300
# ...             ...            ...           ...         ...          ...
# 450.0           NaN            NaN           NaN         NaN            0
# 460.0           NaN            NaN           NaN         NaN            0
# 495.0           NaN            NaN           NaN         NaN            0
# 499.0           NaN            NaN           NaN         NaN            0
# 549.0           NaN            NaN           NaN         NaN            0
# ...

# %% [markdown]
# ### 34. Z-оценка (рассмотрим категории парфюма и ароматов)

# %%
import scipy.stats

# %%
sephora['price'].hist(bins=550)
# Out:
# <AxesSubplot:>

# %%
frag = sephora[sephora['cat'] == 'Fragrance']
frag['price'].hist()
# Out:
# <AxesSubplot:>

# %%
perf = sephora[sephora['cat'] == 'Perfume']
perf['price'].hist()
# Out:
# <AxesSubplot:>

# %%
x = frag['price'][0]
mean = frag['price'].mean()
std = frag['price'].std(ddof=0)
print(x, mean, std)
# Out:
# 66.0 43.7 17.564452738414598

# %%
z_score = (x - mean) / std
print(z_score)
# Out:
# 1.2696097243740734

# %%
scipy.stats.zscore(frag['price'])
# Out:
# 0       1.269610
# 4       1.611209
# 15      2.066674
# 45     -0.779984
# 466     0.643345
# 472    -1.121583
# 1618    0.244813
# 1621   -0.893851
# 2147    0.244813
# 2205    0.244813
# 5389    0.643345
# 5830    0.130946
# 5990    0.586412
# 5993    0.586412
# 7550   -0.836918
# 7645   -1.406249
# 8119   -1.349316
# 8120    0.244813
# 8597   -1.463183
# 8635   -0.666118
# Name: price, dtype: float64

# %%
frag['z_score'] = scipy.stats.zscore(frag['price'])
# Out:
# /var/folders/l7/j8jzwtl53wj2g2m9zwt6tcvh0000gn/T/ipykernel_13671/3343399051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frag['z_score'] = scipy.stats.zscore(frag['price'])

# %%
frag.head()
# Out:
#           id            brand        cat  \
# 0    2218774   Acqua Di Parma  Fragrance
# 4    2218766   Acqua Di Parma  Fragrance
# 15   2295228   Acqua Di Parma  Fragrance
# 45   2350031            AERIN  Fragrance
# 466  2328615  Atelier Cologne  Fragrance
#
#                                                   name              size  \
# 0                       Blu Mediterraneo MINIATURE Set    5 x 0.16oz/5mL
# 4                                Colonia Miniature Set    5 x 0.16oz/5mL
# 15   Blu Mediterraneo Discovery Collection Rollerba...           no size
# 45          Mini Amber Musk Eau de Parfum Travel Spray     0.27 oz/ 8 mL
# 466                          Mini Perfume Wardrobe Set  8 x 0.13 oz/ 4mL
#
#      rating  reviews    love  price  v_price  ...  excl ltd_edition ltd_time  \
# 0       4.0        4    high   66.0     75.0  ...     0           0        0
# 4       3.5        2  medium   72.0     80.0  ...     0           0        0
# ...

# %%
perf['z_score'] = scipy.stats.zscore(perf['price'])
perf.head()
# Out:
# /var/folders/l7/j8jzwtl53wj2g2m9zwt6tcvh0000gn/T/ipykernel_13671/1797177463.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   perf['z_score'] = scipy.stats.zscore(perf['price'])
#         id           brand      cat                   name            size  \
# 2  1417567  Acqua Di Parma  Perfume       Arancia di Capri    5 oz/ 148 mL
# 3  1417617  Acqua Di Parma  Perfume       Mirto di Panarea   2.5 oz/ 74 mL
# 5  1417609  Acqua Di Parma  Perfume         Fico di Amalfi    5 oz/ 148 mL
# 6  1638832  Acqua Di Parma  Perfume            Rosa Nobile  3.4 oz/ 101 mL
# 9  2221596  Acqua Di Parma  Perfume  Rosa Nobile Hair Mist      1.7oz/50mL
#
#    rating  reviews  love  price  v_price  ...  excl ltd_edition ltd_time ltd  \
# ...

# %%
cat_new = pd.concat([frag, perf])
cat_new
# Out:
#            id               brand        cat  \
# 0     2218774      Acqua Di Parma  Fragrance
# 4     2218766      Acqua Di Parma  Fragrance
# 15    2295228      Acqua Di Parma  Fragrance
# 45    2350031               AERIN  Fragrance
# 466   2328615     Atelier Cologne  Fragrance
# ...       ...                 ...        ...
# 8954  2047751       The 7 Virtues    Perfume
# 8959  2047744       The 7 Virtues    Perfume
# 8960  2047777       The 7 Virtues    Perfume
# 8962  2047769       The 7 Virtues    Perfume
# 9102  1788991  SEPHORA COLLECTION    Perfume
#
#                                                    name              size  \
# 0                        Blu Mediterraneo MINIATURE Set    5 x 0.16oz/5mL
# 4                                 Colonia Miniature Set    5 x 0.16oz/5mL
# 15    Blu Mediterraneo Discovery Collection Rollerba...           no size
# 45           Mini Amber Musk Eau de Parfum Travel Spray     0.27 oz/ 8 mL
# ...

# %%
cat_new['z_score'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### Из данных мы видим, что большинство парфюма и ароматов стоят свыше 150$

# %%
cat_new[cat_new['z_score'] > 3]
# Out:
#            id     brand      cat                            name  \
# 4452  2056935    Kilian  Perfume              Love, Don't be Shy
# 8187  2056208  TOM FORD  Perfume                Fucking Fabulous
# 8194  2318756  TOM FORD  Perfume                      Rose Prick
# 8197  2101293  TOM FORD  Perfume                     Lost Cherry
# 8269  1634096  TOM FORD  Perfume                       Café Rose
# 8277  2174233  TOM FORD  Perfume  Lavender Extreme Eau de Parfum
#
#                 size  rating  reviews  love  price  v_price  ...  excl  \
# 4452   1.7 oz/ 50 mL     4.0       42  high  295.0    295.0  ...     0
# 8187   1.7 oz/ 50 mL     3.5       94  high  335.0    335.0  ...     0
# 8194   1.7 oz/ 50 mL     3.5       20  high  335.0    335.0  ...     0
# 8197     1.7oz/ 50mL     4.0       60  high  335.0    335.0  ...     0
# 8269  3.4 oz/ 100 mL     4.5       22  high  325.0    325.0  ...     0
# 8277      1.7oz/50mL     4.0       16  high  335.0    335.0  ...     0
#
# ...

# %% [markdown]
# ###### Всего 6 продуктов (или 2 бренда Kilian & TOM FORD) из категории парфюма и ароматов стоят выше, чем 3 стандартных отклонения от среднего

# %%
cat_new.groupby('rating')['z_score'].mean()
# Out:
# rating
# 0.0    0.637922
# 1.0    0.033467
# 2.0    1.140803
# 2.5   -0.765267
# 3.0   -0.397668
# 3.5    0.394126
# 4.0   -0.020221
# 4.5   -0.073972
# 5.0    0.049397
# Name: z_score, dtype: float64

# %%
cat_new.groupby('love')['z_score'].mean()
# Out:
# love
# high     -0.033589
# low       0.127037
# medium    0.111233
# Name: z_score, dtype: float64

# %% [markdown]
# ###### Из данных выше мы видим, что цена не влияет на рейтинг парфюма и аромата (т.е. не факт, что, чем дороже продукт, тем он лучше/качественнее/приятнее и т.д.), а также, что у более дорогих ароматов и парфомов более низкое кол-во лайков/добавлений в избранное (вероятно, что ядро ЦА - люди, которые не готовы покупать дорогие парфюмы и ароматы).

# %% [markdown]
# ### 35. Выбросы

# %%
sephora['price'].describe()
# Out:
# count    9168.000000
# mean       50.063237
# std        47.164989
# min         2.000000
# 25%        24.000000
# 50%        35.000000
# 75%        59.000000
# max       549.000000
# Name: price, dtype: float64

# %%
q3 = np.percentile(sephora['price'], 75)
q1 = np.percentile(sephora['price'], 25)
print(q3, q1)
# Out:
# 59.0 24.0

# %%
iqr = q3 - q1
print(iqr)
# Out:
# 35.0

# %%
iqr_threshold_bottom = q1 - 1.5 * iqr
iqr_threshold_top = q3 + 1.5 * iqr
print(iqr_threshold_bottom, iqr_threshold_top)
# Out:
# -28.5 111.5

# %%
sephora[sephora['price'] > iqr_htreshold_top].shape
# Out:
# (743, 26)

# %%
sephora[sephora['price'] > iqr_htreshold_top]['cat'].value_counts()
# Out:
# Perfume                            270
# Face Serums                         64
# Moisturizers                        52
# Value & Gift Sets                   46
# Cologne                             35
# Perfume Gift Sets                   34
# Hair Straighteners & Flat Irons     24
# Eye Creams & Treatments             23
# Curling Irons                       22
# Anti-Aging                          19
# Hair Dryers                         18
# Facial Cleansing Brushes            18
# Eye Palettes                        17
# Face Masks                          10
# Face Oils                            9
# Rollerballs & Travel Size            7
# Mists & Essences                     7
# Cologne Gift Sets                    5
# Night Creams                         5
# Body Lotions & Body Oils             5
# Facial Peels                         4
# Face Brushes                         4
# Sheet Masks                          4
# Holistic Wellness                    3
# ...

# %% [markdown]
# ###### Самые дорогие товары представлены в категории "парфюм", а самые дешевые в категории "для истонченных волос и против выпадения волос"

# %%
mean = sephora['price'].mean()
std = sephora['price'].std()
std_threshold_bottom = mean - 2.5 * std
std_threshold_top = mean + 2.5 * std
print(std_threshold_bottom, std_threshold_top)
# Out:
# -67.8492353472576 167.97571004184744

# %%
sephora[sephora['price'] > std_threshold_top].shape
# Out:
# (292, 26)

# %%
iqr_no_outliers = sephora[sephora['price'] <= iqr_threshold_top]
std_no_outliers = sephora[sephora['price'] <= std_threshold_top]

# %%
print(sephora['price'].mean())
print(iqr_no_outliers['price'].mean())
print(std_no_outliers['price'].mean())
# Out:
# 50.063237347294915
# 39.02359169139461
# 43.84877872915725

# %%
print(sephora['price'].median())
print(iqr_no_outliers['price'].median())
print(std_no_outliers['price'].median())
# Out:
# 35.0
# 32.0
# 34.0

# %% [markdown]
# ### 36. Корреляция

# %%
sephora.groupby(sephora['rating'])['price'].mean()
# Out:
# rating
# 0.0    55.422864
# 1.0    65.543478
# 1.5    28.777778
# 2.0    45.397436
# 2.5    41.369318
# 3.0    42.350617
# 3.5    45.455718
# 4.0    48.251970
# 4.5    49.892898
# 5.0    63.406984
# Name: price, dtype: float64

# %%
price_mean = sephora.groupby(sephora['rating'])['price'].mean()
sephora_sum = sephora.groupby(sephora['rating'])['love_cat'].sum()

# %%
sephora_rate = pd.concat([price_mean, sephora_sum], axis=1)

# %%
first_five = sephora_rate.iloc[:5]
first_five
# Out:
#             price  love_cat
# rating
# 0.0     55.422864    290061
# 1.0     65.543478     12668
# 1.5     28.777778     12924
# 2.0     45.397436    108165
# 2.5     41.369318    217892

# %%
first_five['x - Mx'] = first_five['price'] - first_five['price'].mean()
first_five['y - My'] = first_five['love_cat'] - first_five['love_cat'].mean()
# Out:
# /var/folders/l7/j8jzwtl53wj2g2m9zwt6tcvh0000gn/T/ipykernel_13671/1116417669.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_five['x - Mx'] = first_five['price'] - first_five['price'].mean()
# /var/folders/l7/j8jzwtl53wj2g2m9zwt6tcvh0000gn/T/ipykernel_13671/1116417669.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_five['y - My'] = first_five['love_cat'] - first_five['love_cat'].mean()

# %%
first_five
# Out:
#             price  love_cat     x - Mx    y - My
# rating
# 0.0     55.422864    290061   8.120689  161719.0
# 1.0     65.543478     12668  18.241303 -115674.0
# 1.5     28.777778     12924 -18.524397 -115418.0
# 2.0     45.397436    108165  -1.904739  -20177.0
# 2.5     41.369318    217892  -5.932857   89550.0

# %%
SSx = (first_five['x - Mx'] ** 2).sum()
SSy = (first_five['y - My'] ** 2).sum()
SP = (first_five['x - Mx'] * first_five['y - My']).sum()
print(SSx, SSy, SP)
# Out:
# 780.6708532336469 61281137790.0 848418.7144020029

# %%
r = SP / np.sqrt(SSx * SSy)
print(r)
# Out:
# 0.12266279237425527

# %%
first_five['price'].corr(first_five['love_cat'])
# Out:
# 0.12266279237425529

# %%
sephora_rate.plot('price', 'love_cat', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='price', ylabel='love_cat'>

# %%
sephora_rate['price'].corr(sephora_rate['love_cat'])
# Out:
# 0.03530804739376189

# %% [markdown]
# ###### Анализ показал, что корреляции между ценой и кол-вом лайков/добавлений товаров в избранное нет.

# %%
sephora.corr()
# Out:
#                    id    rating   reviews     price   v_price        MF  \
# id           1.000000 -0.176684 -0.175482 -0.026661 -0.004168  0.283722
# rating      -0.176684  1.000000  0.081478  0.019559  0.001941 -0.108410
# reviews     -0.175482  0.081478  1.000000 -0.084001 -0.088855 -0.096984
# price       -0.026661  0.019559 -0.084001  1.000000  0.983357 -0.056920
# v_price     -0.004168  0.001941 -0.088855  0.983357  1.000000 -0.028660
# MF           0.283722 -0.108410 -0.096984 -0.056920 -0.028660  1.000000
# online       0.153745 -0.123342 -0.137082  0.117250  0.130658  0.578973
# excl         0.199285 -0.001908  0.003799 -0.178809 -0.159005  0.627080
# ltd_edition  0.200357 -0.130471 -0.066661  0.015333  0.079754  0.332344
# ltd_time    -0.008607  0.006164  0.000742 -0.009679 -0.009874  0.018908
# ltd          0.199239 -0.129709 -0.066421  0.014685  0.078906  0.332562
# h_love      -0.184857  0.355022  0.128891 -0.109732 -0.116228 -0.126477
# ...

# %%
rat = sephora.groupby(sephora['reviews'])['rating'].mean()
v_pr = sephora.groupby(sephora['reviews'])['v_price'].mean()

# %%
sephora_rate = pd.concat([sephora_rate, rat, v_pr], axis = 1)

# %%
sephora_rate.corr()
# Out:
#              price  love_cat    rating   v_price
# price     1.000000  0.035308 -0.078753  0.055933
# love_cat  0.035308  1.000000  0.225166 -0.457902
# rating   -0.078753  0.225166  1.000000  0.052827
# v_price   0.055933 -0.457902  0.052827  1.000000

# %%
sephora_rate.plot('rating', 'price', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='rating', ylabel='price'>

# %%
sephora_rate.plot('love_cat', 'rating', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='love_cat', ylabel='rating'>

# %%
sephora_rate.plot('rating', 'v_price', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='rating', ylabel='v_price'>

# %%
sephora_rate.corr()['price'].sort_values()
# Out:
# rating     -0.078753
# love_cat    0.035308
# v_price     0.055933
# price       1.000000
# Name: price, dtype: float64

# %%
sephora_rate.corr()['price'].apply(np.abs).sort_values()
# Out:
# love_cat    0.035308
# v_price     0.055933
# rating      0.078753
# price       1.000000
# Name: price, dtype: float64

# %%
corr = sephora_rate.corr()

# %%
corr.abs().unstack().sort_values()
# Out:
# price     love_cat    0.035308
# love_cat  price       0.035308
# rating    v_price     0.052827
# v_price   rating      0.052827
# price     v_price     0.055933
# v_price   price       0.055933
# price     rating      0.078753
# rating    price       0.078753
# love_cat  rating      0.225166
# rating    love_cat    0.225166
# love_cat  v_price     0.457902
# v_price   love_cat    0.457902
# price     price       1.000000
# love_cat  love_cat    1.000000
# rating    rating      1.000000
# v_price   v_price     1.000000
# dtype: float64

# %% [markdown]
# ###### Можем увидеть, что более сильная корреляция у стоимости и товаров, которые добавили в избранное/лайкнули

# %% [markdown]
# ### 37. Визуализация данных

# %%
import matplotlib.pyplot as plt

# %%
sephora_love = sephora.groupby(sephora['love'])['price'].mean()
sephora_love
# Out:
# love
# high      47.740633
# low       59.160134
# medium    64.364395
# Name: price, dtype: float64

# %%
plt.bar(sephora_love.index, sephora_love, color='green')
# Out:
# <BarContainer object of 3 artists>

# %%
fig, ax = plt.subplots(figsize=(10, 5))

ax.bar(sephora_love.index, sephora_love, color='orange')
# Out:
# <BarContainer object of 3 artists>

# %%
sephora_sum = sephora.groupby(sephora['rating'])['price'].sum()
sephora_sum
# Out:
# rating
# 0.0     22058.30
# 1.0      1507.50
# 1.5       259.00
# 2.0      1770.50
# 2.5      3640.50
# 3.0     13043.99
# 3.5     47773.96
# 4.0    137662.87
# 4.5    175972.25
# 5.0     55290.89
# Name: price, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(sephora_sum)

# %%
lr = sephora.groupby(['love', 'reviews'])['price'].sum()
lr
# Out:
# love    reviews
# high    0          1728.30
#         1          2489.50
#         2          5567.99
#         3          5242.49
#         4          5634.00
#                     ...
# medium  13000         0.00
#         14000         0.00
#         15000         0.00
#         17000         0.00
#         19000         0.00
# Name: price, Length: 2499, dtype: float64

# %%
lr.loc['medium']
# Out:
# reviews
# 0        3298.0
# 1        6514.0
# 2        4522.0
# 3        5148.0
# 4        4069.0
#           ...
# 13000       0.0
# 14000       0.0
# 15000       0.0
# 17000       0.0
# 19000       0.0
# Name: price, Length: 833, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(lr.loc['high'])
ax.plot(lr.loc['medium'])
ax.plot(lr.loc['low'])
ax.legend(['high', 'medium', 'low'], frameon=False)

# %%
lr_m = sephora.groupby(['love', 'reviews'])['price'].mean()
lr_m
# Out:
# love    reviews
# high    0          36.006250
#         1          45.263636
#         2          65.505765
#         3          56.983587
#         4          52.654206
#                      ...
# medium  13000            NaN
#         14000            NaN
#         15000            NaN
#         17000            NaN
#         19000            NaN
# Name: price, Length: 2499, dtype: float64

# %%
fig, ax = plt.subplots(2,2, figsize=(20,15))

ax[0][0].plot(lr_m.loc['high'], c='brown')
ax[0][1].plot(lr_m.loc['medium'], c='brown')
ax[1][0].plot(lr_m.loc['low'], c='brown')

for axis in ax.ravel():
    axis.set_ylim(0,300)
    axis.set_xlabel('love')
    axis.set_ylabel('reviews')
    axis.spines['right'].set_visible(False)
    axis.spines['top'].set_visible(False)
    
ax[0][0].legend(['high', 'average'], frameon=False)
ax[0][1].legend(['medium', 'average'], frameon=False)
ax[1][0].legend(['low', 'average'], frameon=False)

fig.suptitle('Table 1', fontsize = 25)
# Out:
# Text(0.5, 0.98, 'Table 1')

# %%
fig.savefig('table_1.pdf')

# %%
fig.savefig('table_1.png', dpi=100)

# %%
import seaborn as sns

# %%
N = 10 ** 4
np.random.seed(42)

def plot_comparison(x, title):
    fig, ax = plt.subplots(3, 1, sharex=True, figsize=(15,10))
    sns.distplot(x, ax=ax[0])
    ax[0].set_title('Histogram + KDE')
    sns.boxplot(x=x, ax=ax[1])
    ax[1].set_title('Boxplot')
    sns.violinplot(x=x, ax=ax[2])
    ax[2].set_title('Violin plot')
    fig.suptitle(title, fontsize=16)
    plt.show()
    
sample_gaussin = np.random.normal(size=N)
plot_comparison(sample_gaussin, 'Standard Normal Distribution')
# Out:
# /Users/annabotsman/Desktop/anaconda/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sample_lognormal = np.random.lognormal(size=N)
plot_comparison(sample_lognormal, 'Log-normal Distribution')
# Out:
# /Users/annabotsman/Desktop/anaconda/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sample_bimodal = np.concatenate([np.random.normal(loc=-2, scale=2, size=int(N/2)),
                                 np.random.normal(loc=3, scale=1, size=int(N/2))])
plot_comparison(sample_bimodal, 'Mixture of Gaussians - bimodal')
# Out:
# /Users/annabotsman/Desktop/anaconda/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
num_features = ['id', 'rating', 'reviews', 'price', 'love_cat']
cat_features = ['online', 'excl', 'ltd_edition', 'ltd_time']

# %%
sns.distplot(sephora['price'])
# Out:
# /Users/annabotsman/Desktop/anaconda/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sephora['excl'].value_counts()
# Out:
# 0    6741
# 1    2427
# Name: excl, dtype: int64

# %%
sns.barplot(x=sephora['excl'].value_counts().index, y=sephora['excl'].value_counts())
# Out:
# <AxesSubplot:ylabel='excl'>

# %%
sns.violinplot(x=sephora['excl'],y=sephora['price'])
# Out:
# <AxesSubplot:xlabel='excl', ylabel='price'>

# %%
sns.boxplot(x=sephora['excl'],y=sephora['price'])
# Out:
# <AxesSubplot:xlabel='excl', ylabel='price'>

# %%
correlation = sephora.corr().loc[num_features, num_features]
correlation
# Out:
#                 id    rating   reviews     price  love_cat
# id        1.000000 -0.176684 -0.175482 -0.026661 -0.104208
# rating   -0.176684  1.000000  0.081478  0.019559  0.094788
# reviews  -0.175482  0.081478  1.000000 -0.084001  0.746099
# price    -0.026661  0.019559 -0.084001  1.000000 -0.088724
# love_cat -0.104208  0.094788  0.746099 -0.088724  1.000000

# %%
fig, ax = plt.subplots(figsize = (15,10))

sns.heatmap(correlation, annot=True, linecolor='white', linewidth=1,
           annot_kws = {'size':15}, vmax=1, vmin=-1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### Видим, что наиболее сильная корреляция у продуктов, которые лайкнули и написали отзывы

# %%
sns.pairplot(sephora[num_features], diag_kind='kde')

# %%
sephora_melted = pd.melt(sephora, id_vars='price', value_vars=cat_features)
sephora_melted
# Out:
#        price  variable  value
# 0       66.0    online      1
# 1       66.0    online      1
# 2      180.0    online      1
# 3      120.0    online      1
# 4       72.0    online      1
# ...      ...       ...    ...
# 36667    6.0  ltd_time      0
# 36668   15.0  ltd_time      0
# 36669   16.0  ltd_time      0
# 36670   50.0  ltd_time      0
# 36671   50.0  ltd_time      0
#
# [36672 rows x 3 columns]

# %%
def boxplot(x, y, **kwargs):
    sns.boxplot(x=x, y=y)
    x=plt.xticks(rotation=90)
    
g = sns.FacetGrid(sephora_melted, col="variable",
                col_wrap=2, sharex=False, sharey=False, height=5)
g.map(boxplot, 'value', 'price')

# %%
# !pip install plotly==4.14.3
# Out:
# ...
#      |████████████████████████████████| 13.2 MB 3.6 MB/s eta 0:00:01
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11447 sha256=8fb4555d7c6cd6657337ee2adb53d743c2c9396dcdfbde057991391b7c8d806d
#   Stored in directory: /Users/annabotsman/Library/Caches/pip/wheels/ce/18/7f/e9527e3e66db1456194ac7f61eb3211068c409edceecff2d31
# Successfully built retrying
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.6.0
#     Uninstalling plotly-5.6.0:
#       Successfully uninstalled plotly-5.6.0
# ...

# %%
import plotly.graph_objects as go
import plotly.express as px

# %%
high = sephora[sephora['love'] == 'high']

# %%
trace = go.Bar(x=high['rating'], y=high['price'])

layout = go.Layout(title='Price depending on rating')

fig = go.Figure(data=trace, layout=layout)
fig
# Out:
# <div>                            <div id="192f9a94-5376-4beb-8d5b-ff7ebd368f8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("192f9a94-5376-4beb-8d5b-ff7ebd368f8c")) {                    Plotly.newPlot(                        "192f9a94-5376-4beb-8d5b-ff7ebd368f8c",                        [{"type": "bar", "x": [4.0, 4.5, 4.5, 4.5, 4.5, 4.5, 3.0, 4.5, 4.5, 4.5, 4.5, 4.0, 4.5, 5.0, 4.5, 4.5, 4.5, 3.5, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.0, 4.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 4.0, 4.5, 4.5, 4.5, 4.0, 4.5, 4.0, 4.0, 4.0, 4.5, 4.5, 4.5, 4.5, 3.5, 4.0, 4.0, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.0, 4.5, 4.0, 4.5, 4.5, 4.0, 4.0, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.0, 4.0, 3.0, 3.5, 3.5, 4.5, 4.0, 4.0, 4.5, 3.5, 5.0, 5.0, 5.0, 4.5, 4.5, 
# ...

# %%
trace = go.Scatter(x=high['rating'], y=high['price'])

layout = go.Layout(title='Price depending on high rating',
                  yaxis={'range':[0,20]})

fig = go.Figure(data=trace, layout=layout)
fig
# Out:
# <div>                            <div id="74af204f-c7f0-4baf-9305-af92c5882b9f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74af204f-c7f0-4baf-9305-af92c5882b9f")) {                    Plotly.newPlot(                        "74af204f-c7f0-4baf-9305-af92c5882b9f",                        [{"type": "scatter", "x": [4.0, 4.5, 4.5, 4.5, 4.5, 4.5, 3.0, 4.5, 4.5, 4.5, 4.5, 4.0, 4.5, 5.0, 4.5, 4.5, 4.5, 3.5, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.0, 4.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 4.0, 4.5, 4.5, 4.5, 4.0, 4.5, 4.0, 4.0, 4.0, 4.5, 4.5, 4.5, 4.5, 3.5, 4.0, 4.0, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.0, 4.5, 4.0, 4.5, 4.5, 4.0, 4.0, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.0, 4.0, 3.0, 3.5, 3.5, 4.5, 4.0, 4.0, 4.5, 3.5, 5.0, 5.0, 5.0, 4.5, 4
# ...

# %% [markdown]
# ###### высокий рейтинг не зависит от цены продукта

# %%
low = sephora[sephora['love'] == 'low']

# %%
trace0 = go.Scatter(x=high['rating'], y=high['price'], name='high')

trace1 = go.Scatter(x=low['rating'], y=low['price'], name='low')

layout = go.Layout(title='Price depending on high & low rating',
                  yaxis={'range':[0,20]})

fig = go.Figure(data=[trace0, trace1], layout=layout)
fig
# Out:
# <div>                            <div id="e26edf1b-d101-43ed-ba73-c814b1dd6278" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e26edf1b-d101-43ed-ba73-c814b1dd6278")) {                    Plotly.newPlot(                        "e26edf1b-d101-43ed-ba73-c814b1dd6278",                        [{"name": "high", "type": "scatter", "x": [4.0, 4.5, 4.5, 4.5, 4.5, 4.5, 3.0, 4.5, 4.5, 4.5, 4.5, 4.0, 4.5, 5.0, 4.5, 4.5, 4.5, 3.5, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.0, 4.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 4.0, 4.5, 4.5, 4.5, 4.0, 4.5, 4.0, 4.0, 4.0, 4.5, 4.5, 4.5, 4.5, 3.5, 4.0, 4.0, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.0, 4.5, 4.0, 4.5, 4.5, 4.0, 4.0, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.0, 4.0, 3.0, 3.5, 3.5, 4.5, 4.0, 4.0, 4.5, 3.5, 5.0, 
# ...

# %% [markdown]
# ###### низкий рейтинг тоже не зависит от цены продукта

# %%
sephora.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9168 entries, 0 to 9167
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           9168 non-null   int64
#  1   brand        9168 non-null   object
#  2   cat          9168 non-null   object
#  3   name         9168 non-null   object
#  4   size         9168 non-null   object
#  5   rating       9168 non-null   float64
#  6   reviews      9168 non-null   int64
#  7   love         9168 non-null   category
#  8   price        9168 non-null   float64
#  9   v_price      9168 non-null   float64
#  10  MF           9168 non-null   bool
#  11  MF_content   9168 non-null   object
#  12  opt          9168 non-null   object
#  13  details      9168 non-null   object
#  14  htu          9168 non-null   object
#  15  ingr         9168 non-null   object
#  16  online       9168 non-null   int64
#  17  excl         9168 non-null   int64
# ...

# %%
sephora.to_pickle('Sephora_hm_1.pkl')

# %%
sephora = pd.read_pickle('Sephora_hm_1.pkl')
sephora.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9168 entries, 0 to 9167
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           9168 non-null   int64
#  1   brand        9168 non-null   object
#  2   cat          9168 non-null   object
#  3   name         9168 non-null   object
#  4   size         9168 non-null   object
#  5   rating       9168 non-null   float64
#  6   reviews      9168 non-null   int64
#  7   love         9168 non-null   category
#  8   price        9168 non-null   float64
#  9   v_price      9168 non-null   float64
#  10  MF           9168 non-null   bool
#  11  MF_content   9168 non-null   object
#  12  opt          9168 non-null   object
#  13  details      9168 non-null   object
#  14  htu          9168 non-null   object
#  15  ingr         9168 non-null   object
#  16  online       9168 non-null   int64
#  17  excl         9168 non-null   int64
# ...
